# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import sys

model = VGG16(weights='imagenet')

def predict(filename, featuresize):
    img = image.load_img(filename, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    preds = model.predict(preprocess_input(x))
    results = decode_predictions(preds, top=featuresize)[0]
    return results

def showimg(filename, title, i):
    im = Image.open(filename)
    im_list = np.asarray(im)
    plt.subplot(2, 5, i)
    plt.title(title)
    plt.axis("off")
    plt.imshow(im_list)

# %%
filename = "dogs-vs-cats/train/cat.3591.jpg"
plt.figure(figsize=(20, 10))
for i in range(1):
    showimg(filename, "query", i+1)
plt.show()
results = predict(filename, 10)
for result in results:
    print(result)
# Out:
# ('n02123045', 'tabby', 0.631754)
# ('n02123159', 'tiger_cat', 0.11595563)
# ('n02909870', 'bucket', 0.018666545)
# ('n02124075', 'Egyptian_cat', 0.018589916)
# ('n03793489', 'mouse', 0.012174862)
# ('n03085013', 'computer_keyboard', 0.0114741335)
# ('n04554684', 'washer', 0.010182994)
# ('n04553703', 'washbasin', 0.009635518)
# ('n04447861', 'toilet_seat', 0.0074380045)
# ('n03642806', 'laptop', 0.0064257677)

# %%
filename = "dogs-vs-cats/train/dog.8035.jpg"
plt.figure(figsize=(20, 10))
for i in range(1):
    showimg(filename, "query", i+1)
plt.show()
results = predict(filename, 10)
for result in results:
    print(result)
# Out:
# ('n02105412', 'kelpie', 0.23042448)
# ('n02096051', 'Airedale', 0.20992477)
# ('n02089078', 'black-and-tan_coonhound', 0.11741924)
# ('n02090379', 'redbone', 0.040014554)
# ('n02107142', 'Doberman', 0.03516299)
# ('n02089867', 'Walker_hound', 0.031187316)
# ('n02088632', 'bluetick', 0.029132968)
# ('n02106550', 'Rottweiler', 0.023665415)
# ('n02088364', 'beagle', 0.018311841)
# ('n02087394', 'Rhodesian_ridgeback', 0.014419642)
